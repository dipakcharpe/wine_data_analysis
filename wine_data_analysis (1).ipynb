# %% [markdown]
# # Wine Data Analysis
#
# - Disclosing the wine quality dataset
# - Analyzing red wine
# - Analyzing white wine
# - we can do all the analysis by concatenating both file upfront but for practice purpuse and concatenate in at last
# - downloded the dataset from "https://archive.ics.uci.edu/ml/datasets/wine+quality"
# - loaded data using pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from matplotlib.ticker import PercentFormatter
import seaborn as sns
sns.set_style("darkgrid")
import scipy.stats as stats

# %%
#load the data using pandas
df_red = pd.read_csv(r"C:\Users\omcha\Downloads\winequality-red.csv")
df_white = pd.read_csv(r"C:\Users\omcha\Downloads\winequality-white.csv")

# %%
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_red.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
#cheaking which type of columns and datape we have in our given dataset
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
#for getting the overview of data
df_red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#cheaking the null values in the data
df_red.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
sns.pairplot(df_red) #to see the ralation between differnt coloums and analysing corr.

# %%
# mapping the correlation between all the columns in dataset
fig, ax = plt.subplots(figsize=(12,10))
sns.heatmap(df_red.corr(),cmap="YlGnBu", annot=True,ax=ax)
plt.show()

# %%
#  total distinct quality count of dataset 
sns.countplot(data =df_red , x ='quality', dodge=False)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
sns.histplot( df_red.alcohol)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Count'>

# %%
#for getting relation between alcohol quantity and quality of alcohol we can do so by using boxplot
ax = sns.boxplot(x=df_red["alcohol"] ,y=df_red["quality"] )
plt.show(ax)

# %%
#using groupBy to find avg alcohol percentage qualitywise
quality_wise_alcohol = df_red.groupby(df_red.quality)['alcohol'].mean().reset_index().rename(columns = {'alcohol':'avg_alcohol_conc'})
quality_wise_alcohol
# Out:
#    quality  avg_alcohol_conc
# 0        3          9.955000
# 1        4         10.265094
# 2        5          9.899706
# 3        6         10.629519
# 4        7         11.465913
# 5        8         12.094444

# %%
#graphical visualysation of quality and acohol percentage
sns.scatterplot(data = quality_wise_alcohol, x='quality',y='avg_alcohol_conc')
plt.show()

# %%
#looking for the correlation between alcohol and pH getting a best fitted line

print("The Rho is {}".format(np.corrcoef(df_red.alcohol, df_red.pH)[0][1]))

g = sns.jointplot(data = df_red, x = "alcohol", y = "pH", kind='reg', color='royalblue')
# ax.annotate(stats.pearsonr)
r, p = stats.pearsonr(df_red.alcohol, df_red.pH)
g.ax_joint.annotate(f'$\\rho = {r:.3f}, p = {p:.3f}$',
                    xy=(0.1, 0.9), xycoords='axes fraction',
                    ha='left', va='center',
                    bbox={'boxstyle': 'round', 'fc': 'powderblue', 'ec': 'navy'})
g.ax_joint.scatter(df_red.alcohol, df_red.pH)
g.set_axis_labels(xlabel="alcohol", ylabel="pH", size=15)
plt.tight_layout()
plt.show()
# Out:
# The Rho is 0.20563250851242024

# %%
#function to find correlation between any two columns in database
a=input("name of the first column:")
b=input("name of the second column:")

def get_correlation (a,b):
    x=df_red[a].corr(df_red[b])
    print(f"The correlation between {a} and {b} is {x}")
get_correlation(a,b)
# Out:
# name of the first column:alcohol
# name of the second column:pH
# The correlation between alcohol and pH is 0.20563250851242024

# %%
#cross cheaking code on line no 97
x=df_red['alcohol'].corr(df_red['pH'])
x
# Out:
# 0.20563250851242024

# %%
avg_quality_red_wine = df_red.quality.mean()
avg_quality_red_wine
#as below i converted quality datatype into categorical form int so this code will show error
# Out:
# 5.6360225140712945

# %%
avg_quality_whitw_wine = df_white.quality.mean()
avg_quality_whitw_wine
#as below i converted quality datatype into categorical form int so this code will show error
# Out:
# 5.87790935075541

# %%
#creating new column in the dataset
df_red['wine_category'] = 'red wine'
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# changing the coloum index in the dataset 
cols = df_red.columns.tolist()
cols
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality',
#  'wine_category']

# %%
cols = cols[-1:] + cols[:-1]
cols
# Out:
# ['wine_category',
#  'fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
#creating new column in the dataset
df_white['wine_category'] = 'white wine'
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# changing the coloum index in the dataset 
cols1 = df_white.columns.tolist()
cols1
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality',
#  'wine_category']

# %%
cols1 = cols1[-1:] + cols1[:-1]
cols1
# Out:
# ['wine_category',
#  'fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
#finding unique wine quality rating
df_red.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
#finding unique wine quality rating
df_white.quality.unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9], dtype=int64)

# %%
#changing the datatype of quality columns from int64 to categorical
df_red['quality'] = pd.Categorical(df_red.quality)
df_red.dtypes
# Out:
# fixed acidity            float64
# volatile acidity         float64
# citric acid              float64
# residual sugar           float64
# chlorides                float64
# free sulfur dioxide      float64
# total sulfur dioxide     float64
# density                  float64
# pH                       float64
# sulphates                float64
# alcohol                  float64
# quality                 category
# wine_category             object
# dtype: object

# %%
#changing the datatype of quality columns from int64 to categorical
df_white['quality'] = pd.Categorical(df_white.quality)
df_white.dtypes
# Out:
# fixed acidity            float64
# volatile acidity         float64
# citric acid              float64
# residual sugar           float64
# chlorides                float64
# free sulfur dioxide      float64
# total sulfur dioxide     float64
# density                  float64
# pH                       float64
# sulphates                float64
# alcohol                  float64
# quality                 category
# wine_category             object
# dtype: object

# %%
# creating new cnditional column in dataset without using lamda function
df_red['quality_label'] = ['low' if x<=5 else ('medium' if x>5 and x<=7 else 'high' ) for x in df_red['quality']]
df_red
#df_red['wine category']= df_red['quality'].apply(lambda x :'low' if x <= 5 else ('medium' if x>5 and x<=7 else 'high' ))
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# creating new cnditional column in dataset using lambda function
df_white['quality_label'] = df_white.quality.apply(lambda x: 'low'if x<=5 else('medium' if x>5 and x<=7 else "high"))
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#counting wine category so that we could get the quality wise differance
quality_wise_category = df_red.groupby(df_red.quality_label)['wine_category'].count().reset_index().rename(columns = {'wine_category':'category_count'})
quality_wise_category
# Out:
#   quality_label  category_count
# 0          high              18
# 1           low             744
# 2        medium             837

# %%
#counting wine category so that we could get the quality wise differance
quality_wise_category = df_white.groupby(df_white.quality_label)['wine_category'].count().reset_index().rename(columns = {'wine_category':'category_count'})
quality_wise_category
# Out:
#   quality_label  category_count
# 0          high             180
# 1           low            1640
# 2        medium            3078

# %%
#concatinating redwine and white wine data
df = pd.concat([df_red ,df_white],axis =0)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#shuffling the columns for further use
df = df.sample(frac = 1)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2746            7.0              0.34         0.30            1.80      0.045
# 288             8.7              0.52         0.09            2.50      0.091
# 4290            5.7              0.26         0.24           17.80      0.059
# 4066            7.1              0.44         0.27            8.40      0.057
# 1554            7.9              0.42         0.49            8.20      0.056
# ...             ...               ...          ...             ...        ...
# 684             9.8              0.98         0.32            2.30      0.078
# 168             7.5              0.29         0.31            8.95      0.055
# 4237            7.5              0.23         0.30            1.20      0.030
# 671             6.6              0.28         0.36            1.70      0.038
# 2567            6.6              0.24         0.28            1.80      0.028
#
# ...

# %%
#col = df.columns.tolist()
#col= col[-2:-1] + col[:]
#col

# %%
#getting columns for further analysis
df_new = df[['alcohol', 'density', 'pH', 'quality']]
df_new
# Out:
#       alcohol  density    pH  quality
# 2746     10.8  0.99140  2.99        6
# 288      10.6  0.99760  3.34        7
# 4290     10.1  0.99773  3.30        5
# 4066     11.8  0.99257  3.16        6
# 1554     11.2  0.99650  3.29        7
# ...       ...      ...   ...      ...
# 684       9.4  0.99800  3.25        5
# 168       9.3  0.99680  3.08        5
# 4237     10.5  0.99192  3.05        5
# 671      11.6  0.99120  3.29        6
# 2567     11.4  0.99182  3.34        5
#
# [6497 rows x 4 columns]

# %%
# creating new df where quality is <=5
low_quality_wine  = df_new[(df_new.quality <= 5)]
low_quality_wine
# Out:
#       alcohol  density    pH  quality
# 4290    10.10  0.99773  3.30        5
# 496      8.60  0.99760  3.08        4
# 1492    11.95  0.99348  3.57        5
# 3835     8.40  0.99429  3.16        5
# 67       9.80  0.99200  3.14        5
# ...       ...      ...   ...      ...
# 296      9.40  0.99760  3.09        5
# 684      9.40  0.99800  3.25        5
# 168      9.30  0.99680  3.08        5
# 4237    10.50  0.99192  3.05        5
# 2567    11.40  0.99182  3.34        5
#
# [2384 rows x 4 columns]

# %%
# creating new df where quality is in between 5 and 7
medium_quality_wine = df_new[( df_new.quality > 5) & (df_new.quality <=7)]
medium_quality_wine
# Out:
#       alcohol  density    pH  quality
# 2746     10.8  0.99140  2.99        6
# 288      10.6  0.99760  3.34        7
# 4066     11.8  0.99257  3.16        6
# 1554     11.2  0.99650  3.29        7
# 2783     10.4  0.99587  3.31        6
# ...       ...      ...   ...      ...
# 4800     11.6  0.99051  3.31        7
# 365      12.3  0.99120  3.40        7
# 118      10.9  0.99620  3.21        6
# 1030     11.5  0.99488  3.42        7
# 671      11.6  0.99120  3.29        6
#
# [3915 rows x 4 columns]

# %%
## creating new df where quality is >7
high_quality_wine= df_new[(df_new.quality >7)]
high_quality_wine
# Out:
#       alcohol  density    pH  quality
# 3665     13.2  0.98856  3.20        8
# 1106     11.2  0.99200  3.55        8
# 4786     12.8  0.98904  3.46        8
# 837      11.9  0.99085  3.25        8
# 1778     11.0  0.99220  3.42        8
# ...       ...      ...   ...      ...
# 158      12.1  0.98940  3.36        8
# 74       10.7  0.99260  3.33        8
# 1283     12.7  0.99270  3.07        8
# 1991      8.9  0.99900  3.14        8
# 1632     12.2  0.99260  3.41        8
#
# [198 rows x 4 columns]

# %%
#single veriable analysis
sns.displot(df.pH)
plt.show()

# %%
df.columns

# %%
#getting numeric columns to find correlation
df1 = df[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']]

# %%
#correlation of df1
fig, ax = plt.subplots(figsize = (14,10))
sns.heatmap(df1.corr(),cmap="Greens" ,annot =True,ax=ax)
plt.show()

# %%
sns.countplot(df.wine_category)
plt.yticks(fontsize =10)
plt.xticks(fontsize = 10)
plt.xlabel(' Wine Category' ,fontsize = 12)
plt.ylabel('Total',fontsize = 12)
plt.title('Wine Category Camparision' , fontsize = 15 , fontweight = 'bold')
plt.show()

# %%
#filter = (df_red["quality"] == 8)
#df_red1 = df_red.where(filter, inplace = True)
#df_red1

# %%
#filtered_df = df_red[df_red["fixed acidity"].notnull()]
#filtered_df

# %%
#a=df_red.dropna(thresh=2)

# %%
#filtered_df = a[a["fixed acidity"].notnull()]
#filtered_df

# %%
#df_red
